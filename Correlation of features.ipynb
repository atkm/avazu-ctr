# %%
import pandas as pd
import numpy as np

from scipy.stats import chi2_contingency

# %%
df = pd.read_csv('data/train_small.csv')
df.hour = pd.to_datetime(df.hour, format="%y%m%d%H")

# %%
def chi2_score(col, other_col):
    obs = pd.crosstab(col, other_col)
    chi2, p, dof, ex = chi2_contingency(obs)
    return chi2, p, obs

# %%
df.columns
# Out:
# Index(['id', 'click', 'hour', 'C1', 'banner_pos', 'site_id', 'site_domain',
#        'site_category', 'app_id', 'app_domain', 'app_category', 'device_id',
#        'device_ip', 'device_model', 'device_type', 'device_conn_type', 'C14',
#        'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'],
#       dtype='object')

# %% [markdown]
# ## banner_pos and click
# They are the features with the smallest cardinalities.

# %%
df_banner_pos_not_null = df[df.banner_pos != 0]
_, p, obs = chi2_score(df_banner_pos_not_null.click, df_banner_pos_not_null.banner_pos)
p
# Out:
# 3.9523722820364723e-44

# %%
obs
# Out:
# banner_pos       1    2   3    4    5    7
# click
# 0           227266  296  36  146  131  664
# 1            51091   39  12   31   19  364

# %% [markdown]
# ## Low cardinality features

# %%
low_cardinality_cols = ['click', 'C1', 'banner_pos', 'site_category',
                        'app_category', 'device_type', 'device_conn_type',
                        'C15', 'C16', 'C18', 'C19', 'C21']
#low_cardinality_cols = ['click', 'C1', 'device_type', 'device_conn_type', 'C15', 'C16']

# %%
import itertools

# %%
pvals = pd.DataFrame(index=low_cardinality_cols, columns=low_cardinality_cols)
for c1, c2 in itertools.combinations(low_cardinality_cols, 2):
    _, p, _ = chi2_score(df[c1], df[c2])
    pvals.loc[c1, c2] = p
pvals
# Out:
#                  click   C1   banner_pos site_category app_category  \
# click              NaN    0  1.1979e-167             0            0
# C1                 NaN  NaN            0             0            0
# banner_pos         NaN  NaN          NaN             0            0
# site_category      NaN  NaN          NaN           NaN            0
# app_category       NaN  NaN          NaN           NaN          NaN
# device_type        NaN  NaN          NaN           NaN          NaN
# device_conn_type   NaN  NaN          NaN           NaN          NaN
# C15                NaN  NaN          NaN           NaN          NaN
# C16                NaN  NaN          NaN           NaN          NaN
# C18                NaN  NaN          NaN           NaN          NaN
# C19                NaN  NaN          NaN           NaN          NaN
# C21                NaN  NaN          NaN           NaN          NaN
#
#                  device_type device_conn_type  C15  C16  C18  C19  C21
# click                      0                0    0    0    0    0    0
# C1                         0                0    0    0    0    0    0
# banner_pos                 0                0    0    0    0    0    0
# site_category              0                0    0    0    0    0    0
# app_category               0                0    0    0    0    0    0
# device_type              NaN                0    0    0    0    0    0
# device_conn_type         NaN              NaN    0    0    0    0    0
# C15                      NaN              NaN  NaN    0    0    0    0
# C16                      NaN              NaN  NaN  NaN    0    0    0
# C18                      NaN              NaN  NaN  NaN  NaN    0    0
# C19                      NaN              NaN  NaN  NaN  NaN  NaN    0
# C21                      NaN              NaN  NaN  NaN  NaN  NaN  NaN

# %% [markdown]
# ## app_id and app_domain

# %%
chi2, p, obs = chi2_score(df.app_category, df.site_category)

# %%
chi2, p
# Out:
# (786112.1963098047, 0.0)

# %%
obs
# Out:
# site_category  0569f928  110ab22d  28905ebd  335d28a8  3e814130  42a36e14  \
# app_category
# 07d7df22            427         1    181991      3326     75290        61
# 09481d60              0         0         0         0         0         0
# 0bfbc358              0         0         0         0         0         0
# 0d82db25              0         0         0         0         0         0
# 0f2161f8              0         0         0         0         0         0
# 0f9a328c              0         0         0         0         0         0
# 18b1e0be              0         0         0         0         0         0
# 2281a340              0         0         0         0         0         0
# 2fc4f2aa              0         0         0         0         0         0
# 4681bb9d              0         0         0         0         0         0
# 4ce2e9fc              0         0         0         0         0         0
# 5326cf99              0         0         0         0         0         0
# 7113d72a              0         0         0         0         0         0
# 71af18ce              0         0         0         0         0         0
# 75d80bbe              0         0         0         0         0         0
# 79f0b860              0         0         0         0         0         0
# 879c24eb              0         0         0         0         0         0
# 8ded1f7a              0         0         0         0         0         0
# 8df2e842              0         0         0         0         0         0
# a3c42688              0         0         0         0         0         0
# a7fd01ec              0         0         0         0         0         0
# a86a3e89              0         0         0         0         0         0
# cef3e649              0         0         0         0         0         0
# d1327cf5              0         0         0         0         0         0
# dc97ec06              0         0         0         0         0         0
# f95efa07              0         0         0         0         0         0
# fc6fa53d              0         0         0         0         0         0
#
# site_category  50e219e0  5378d028  70fb0e29  72722551    ...     8fd0aea4  \
# app_category                                             ...
# 07d7df22          56665        18       598       686    ...          186
# 09481d60           1301         0         0         0    ...            0
# 0bfbc358              8         0         0         0    ...            0
# 0d82db25              3         0         0         0    ...            0
# 0f2161f8         235972         0         0         0    ...            0
# 0f9a328c            139         0         0         0    ...            0
# 18b1e0be              6         0         0         0    ...            0
# 2281a340             55         0         0         0    ...            0
# 2fc4f2aa              5         0         0         0    ...            0
# 4681bb9d            145         0         0         0    ...            0
# 4ce2e9fc            501         0         0         0    ...            0
# 5326cf99              5         0         0         0    ...            0
# 7113d72a              8         0         0         0    ...            0
# 71af18ce              1         0         0         0    ...            0
# 75d80bbe           1042         0         0         0    ...            0
# 79f0b860             15         0         0         0    ...            0
# 879c24eb            345         0         0         0    ...            0
# 8ded1f7a          36390         0         0         0    ...            0
# 8df2e842             36         0         0         0    ...            0
# a3c42688            298         0         0         0    ...            0
# a7fd01ec              4         0         0         0    ...            0
# a86a3e89             67         0         0         0    ...            0
# cef3e649          43035         0         0         0    ...            0
# d1327cf5           3107         0         0         0    ...            0
# dc97ec06           1280         0         0         0    ...            0
# f95efa07          28160         0         0         0    ...            0
# fc6fa53d            548         0         0         0    ...            0
#
# site_category  9ccfa2ea  a818d37a  bcf865d9  c0dd3be3  c706e647  dedf689d  \
# app_category
# 07d7df22              5        79        24      1087         1       571
# 09481d60              0         0         0         0         0         0
# 0bfbc358              0         0         0         0         0         0
# 0d82db25              0         0         0         0         0         0
# 0f2161f8              0         0         0         0         0         0
# 0f9a328c              0         0         0         0         0         0
# 18b1e0be              0         0         0         0         0         0
# 2281a340              0         0         0         0         0         0
# 2fc4f2aa              0         0         0         0         0         0
# 4681bb9d              0         0         0         0         0         0
# 4ce2e9fc              0         0         0         0         0         0
# 5326cf99              0         0         0         0         0         0
# 7113d72a              0         0         0         0         0         0
# 71af18ce              0         0         0         0         0         0
# 75d80bbe              0         0         0         0         0         0
# 79f0b860              0         0         0         0         0         0
# 879c24eb              0         0         0         0         0         0
# 8ded1f7a              0         0         0         0         0         0
# 8df2e842              0         0         0         0         0         0
# a3c42688              0         0         0         0         0         0
# a7fd01ec              0         0         0         0         0         0
# a86a3e89              0         0         0         0         0         0
# cef3e649              0         0         0         0         0         0
# d1327cf5              0         0         0         0         0         0
# dc97ec06              0         0         0         0         0         0
# f95efa07              0         0         0         0         0         0
# fc6fa53d              0         0         0         0         0         0
#
# site_category  e787de0e  f028772b  f66779e6
# app_category
# 07d7df22             34    313740      6278
# 09481d60              0         0         0
# 0bfbc358              0         0         0
# 0d82db25              0         0         0
# 0f2161f8              0         0         0
# 0f9a328c              0         0         0
# 18b1e0be              0         0         0
# 2281a340              0         0         0
# 2fc4f2aa              0         0         0
# 4681bb9d              0         0         0
# 4ce2e9fc              0         0         0
# 5326cf99              0         0         0
# 7113d72a              0         0         0
# 71af18ce              0         0         0
# 75d80bbe              0         0         0
# 79f0b860              0         0         0
# 879c24eb              0         0         0
# 8ded1f7a              0         0         0
# 8df2e842              0         0         0
# a3c42688              0         0         0
# a7fd01ec              0         0         0
# a86a3e89              0         0         0
# cef3e649              0         0         0
# d1327cf5              0         0         0
# dc97ec06              0         0         0
# f95efa07              0         0         0
# fc6fa53d              0         0         0
#
# [27 rows x 22 columns]

# %% [markdown]
# ## site_id and site_domain
# They should be correlated, but the chi2 statistic is huge---too many zero entries.

# %%
df.site_id.nunique(), df.site_domain.nunique()
# Out:
# (2667, 2875)

# %%
obs = pd.crosstab(df.site_id, df.site_domain)
chi2, p, dof, ex = chi2_contingency(obs)
chi2, p
# Out:
# (1691595879.2559881, 0.0)

# %% [markdown]
# ## Example scipy.stats.chi2_contingency

# %%
# independent case
k = 3 # the number of categories
n = int(1e5)
x = np.random.randint(k, size=n)
y = np.random.randint(k, size=n)
obs = pd.crosstab(x, y)
obs
# Out:
# col_0      0      1      2
# row_0
# 0      11032  11016  11273
# 1      11186  11170  11051
# 2      11007  11016  11249

# %%
chi2, p, dof, ex = chi2_contingency(obs)

# %%
# p is large because x and y are independent
# (p := integrate the chi2 distribution from the chi2 value reported to infty) 
chi2, p, dof, ex
# Out:
# (5.492058682497643,
#  0.24042841016763603,
#  4,
#  array([[11070.90225, 11063.23842, 11186.85933],
#         [11099.47575, 11091.79214, 11215.73211],
#         [11054.622  , 11046.96944, 11170.40856]]))

# %%
# dependent case
k = 3 # the number of categories
n = int(1e5)
x = np.random.randint(k, size=n)
y = np.mod(x+1, 3)
obs = pd.crosstab(x, y)
obs
# Out:
# col_0      0      1      2
# row_0
# 0          0  33393      0
# 1          0      0  33361
# 2      33246      0      0

# %%
chi2, p, dof, ex = chi2_contingency(obs)
# chi2 is large, and p is small because x and y are correlated.
chi2, p, dof, ex
# Out:
# (200000.0, 0.0, 4, array([[11101.83678, 11150.92449, 11140.23873],
#         [11091.19806, 11140.23873, 11129.56321],
#         [11052.96516, 11101.83678, 11091.19806]]))
